# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
requests.__version__
# Out:
# '2.27.1'

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Kansas"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748&q=Kansas

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# call the response code with the get() method using the status_code
city_weather.status_code
# Out:
# 200

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-98.5006,"lat":38.5003},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"base":"stations","main":{"temp":90.16,"feels_like":86.4,"temp_min":89.87,"temp_max":90.25,"pressure":1018,"humidity":19,"sea_level":1018,"grnd_level":959},"visibility":10000,"wind":{"speed":9.71,"deg":81,"gust":9.64},"clouds":{"all":0},"dt":1661887736,"sys":{"type":2,"id":2008008,"country":"US","sunrise":1661860908,"sunset":1661908072},"timezone":-18000,"id":4273857,"name":"Kansas","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -98.5006, 'lat': 38.5003},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 90.16,
#   'feels_like': 86.4,
#   'temp_min': 89.87,
#   'temp_max': 90.25,
#   'pressure': 1018,
#   'humidity': 19,
#   'sea_level': 1018,
#   'grnd_level': 959},
#  'visibility': 10000,
#  'wind': {'speed': 9.71, 'deg': 81, 'gust': 9.64},
#  'clouds': {'all': 0},
#  'dt': 1661887736,
#  'sys': {'type': 2,
#   'id': 2008008,
#   'country': 'US',
#   'sunrise': 1661860908,
#   'sunset': 1661908072},
#  'timezone': -18000,
#  'id': 4273857,
#  'name': 'Kansas',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Kansas"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Import the dependencies.
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# For each city in our lats_lngs list, we need to retrieve the following data and add it to a DataFrame:

# City, country, and date

# Latitude and longitude

# Maximum temperature

# Humidity

# Cloudiness

# Wind speed

# %%
# Get the JSON data.
Kansas_data = city_weather.json()

# %%
Kansas_data['sys']["country"]
# Out:
# 'US'

# %%
Kansas_data['coord']['lat']
# Out:
# 38.5003

# %%
lat = Kansas_data["coord"]["lat"]

lng = Kansas_data["coord"]["lon"]

max_temp = Kansas_data["main"]["temp_max"]

humidity = Kansas_data["main"]["humidity"]

clouds = Kansas_data["clouds"]["all"]

wind = Kansas_data["wind"]["speed"]

print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 38.5003 -98.5006 90.25 19 0 9.71

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Get the date from the JSON file.
date = Kansas_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 8, 30, 19, 28, 56)

# %%
# We can convert this datetime format to 2019-10-21 17:24:35 using the Python string format method strftime()
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-08-30 19:28:56'

# %%
# Import the dependencies.
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)

lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
pip install citipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
class City:
    '''
    City wraps up the info about a city, including its name, coordinates,
    and belonging country.
    '''
    def __init__(self, city_name, country_code):
        self.city_name = city_name
        
        
        self.country_code = country_code

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# new norfolk au
# zhigansk ru
# vaini to
# bengkulu id
# provideniya ru
# lebu cl
# hobart au
# karpogory ru
# kavieng pg
# butaritari ki
# andenes no
# saldanha za
# bambous virieux mu
# nizhneyansk ru
# geraldton au
# dikson ru
# puerto ayora ec
# faanui pf
# albany au
# sorvag fo
# puerto ayora ec
# ancud cl
# saleaula ws
# sitka us
# busselton au
# kavieng pg
# santa cruz cr
# belaya gora ru
# prado br
# vestmanna fo
# port elizabeth za
# galgani sd
# zyryanka ru
# constitucion mx
# carnarvon au
# amderma ru
# cedral mx
# longyearbyen sj
# bluff nz
# cape town za
# buin pg
# taolanaro mg
# busselton au
# bredasdorp za
# sabang id
# bengkulu id
# zaraysk ru
# ponta do sol pt
# kaitangata nz
# new norfolk au
# ushuaia ar
# svetlogorsk ru
# albany au
# ixtapa mx
# avarua ck
# cockburn town bs
# guamuchil mx
# georgetown sh
# hobart au
# san patricio mx
# busselton au
# vaini to
# sobolevo ru
# butaritari ki
# puerto ayora ec
# scharding at
# cape town za
# varzelandia br
# sola vu
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 593

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
 

print("-----------------------------")

# Create counters.
record_count = 1

set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        record_count = 1
        
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
# city_url = url + "&q=" + 'cape town'


    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
# print(city_weather)
    # Parse out the needed data.
        city_name = city_weather["name"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather['dt']
         # Append the city information into city_data list.
        city_data.append({"City": city_name,
                       "Lat": city_lat,
                      "Lng": city_lng,
                       "Max Temp": city_max_temp,
                       "Humidity": city_humidity,
                       "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                       "Country": city_country, 
                        "date": datetime.utcfromtimestamp(city_date).strftime('%Y-%m-%d %H:%M:%S') })
        # print(city_data)

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
             
# print("-----------------------------")
  # print("Data Retrieval Complete      ")
 # print("-----------------------------")
# Out:
# -----------------------------
# Processing Record 1 of Set 12 | new norfolk
# Processing Record 2 of Set 12 | zhigansk
# Processing Record 3 of Set 12 | vaini
# Processing Record 4 of Set 12 | bengkulu
# Processing Record 5 of Set 12 | provideniya
# Processing Record 6 of Set 12 | lebu
# Processing Record 7 of Set 12 | hobart
# Processing Record 8 of Set 12 | karpogory
# Processing Record 9 of Set 12 | kavieng
# Processing Record 10 of Set 12 | butaritari
# Processing Record 11 of Set 12 | andenes
# Processing Record 12 of Set 12 | saldanha
# Processing Record 13 of Set 12 | bambous virieux
# Processing Record 14 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 12 | geraldton
# Processing Record 16 of Set 12 | dikson
# Processing Record 17 of Set 12 | puerto ayora
# Processing Record 18 of Set 12 | faanui
# Processing Record 19 of Set 12 | albany
# Processing Record 20 of Set 12 | sorvag
# City not found. Skipping...
# ...

# %%
print(city_data)
# Out:
# [{'City': 'New Norfolk', 'Lat': -42.7826, 'Lng': 147.0587, 'Max Temp': 51.71, 'Humidity': 81, 'Cloudiness': 100, 'Wind Speed': 4, 'Country': 'AU', 'date': '2022-08-30 19:29:02'}, {'City': 'Zhigansk', 'Lat': 66.7697, 'Lng': 123.3711, 'Max Temp': 43.61, 'Humidity': 90, 'Cloudiness': 71, 'Wind Speed': 5.64, 'Country': 'RU', 'date': '2022-08-30 19:29:02'}, {'City': 'Vaini', 'Lat': -21.2, 'Lng': -175.2, 'Max Temp': 68.16, 'Humidity': 100, 'Cloudiness': 75, 'Wind Speed': 6.91, 'Country': 'TO', 'date': '2022-08-30 19:29:04'}, {'City': 'Bengkulu', 'Lat': -3.8004, 'Lng': 102.2655, 'Max Temp': 75.34, 'Humidity': 91, 'Cloudiness': 95, 'Wind Speed': 4.07, 'Country': 'ID', 'date': '2022-08-30 19:29:05'}, {'City': 'Provideniya', 'Lat': 64.3833, 'Lng': -173.3, 'Max Temp': 48.47, 'Humidity': 98, 'Cloudiness': 100, 'Wind Speed': 13.18, 'Country': 'RU', 'date': '2022-08-30 19:29:05'}, {'City': 'Lebu', 'Lat': -37.6167, 'Lng': -73.65, 'Max Temp': 54.3, 'Humidity': 81, 'Cloudiness': 100, 'Wind Speed': 3.
# ...

# %%
import pandas as pd

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
df_weather = pd.DataFrame(city_data, columns=['City',"Lat" ,"Lng" ,"Max Temp" ,"Humidity" ,"Cloudiness" ,"Wind Speed","Country", "date"])
# json = dataFrame.to_json()
# json.head(10)
df_weather.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  New Norfolk -42.7826  147.0587     51.71        81         100        4.00
# 1     Zhigansk  66.7697  123.3711     43.61        90          71        5.64
# 2        Vaini -21.2000 -175.2000     68.16       100          75        6.91
# 3     Bengkulu  -3.8004  102.2655     75.34        91          95        4.07
# 4  Provideniya  64.3833 -173.3000     48.47        98         100       13.18
#
#   Country                 date
# 0      AU  2022-08-30 19:29:02
# 1      RU  2022-08-30 19:29:02
# 2      TO  2022-08-30 19:29:04
# 3      ID  2022-08-30 19:29:05
# 4      RU  2022-08-30 19:29:05

# %%
df_sample=df_weather.head(20)
df_sample
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       New Norfolk -42.7826  147.0587     51.71        81         100
# 1          Zhigansk  66.7697  123.3711     43.61        90          71
# 2             Vaini -21.2000 -175.2000     68.16       100          75
# 3          Bengkulu  -3.8004  102.2655     75.34        91          95
# 4       Provideniya  64.3833 -173.3000     48.47        98         100
# 5              Lebu -37.6167  -73.6500     54.30        81         100
# 6            Hobart -42.8794  147.3294     52.05        74         100
# 7         Karpogory  64.0019   44.4451     49.23        83         100
# 8           Kavieng  -2.5744  150.7967     81.18        81          47
# 9        Butaritari   3.0707  172.7902     81.57        77          14
# 10          Andenes  69.3143   16.1194     49.98        87          75
# 11         Saldanha -33.0117   17.9442     57.25        46           0
# ...

# %%
# Create the output file (CSV).
output_data_file = "cities2.csv"
# Export the City_Data into a CSV.
df_sample.to_csv(output_data_file, index_label="City_ID")

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1661887957.6996255

# %% [markdown]
# # CSV1

# %%
# Import dependencies
import pathlib as Path
import pandas as pd

# %%
# File to load
first_file_to_load = "Resources/cities1.csv"
second_file_to_load = "Resources/cities2.csv"

# %%
# Load csv1 data 
first_cities_df =pd.read_csv("Resources/cities1.csv")
first_cities_df.head(10)
# Out:
#    City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 0        0  Satellite Beach  28.1761  -80.5901     92.05        68
# 1        1         Yuanping  38.7153  112.7575     62.10        63
# 2        2        Busselton -33.6500  115.3333     50.67        83
# 3        3           Atuona  -9.8000 -139.0333     76.73        69
# 4        4          Zhangye  38.9342  100.4517     71.51        28
# 5        5           Castro -24.7911  -50.0119     56.52        64
# 6        6          Ushuaia -54.8000  -68.3000     47.86        61
# 7        7     Saint George  37.1041 -113.5841     86.79        31
# 8        8             Hofn  64.2539  -15.2082     52.99        98
# 9        9        Nantucket  41.2835  -70.0995     82.54        78
#
#    Cloudiness  Wind Speed Country                 date
# 0           0       12.66      US  2022-08-30 16:25:49
# 1           2        1.50      CN  2022-08-30 16:25:50
# 2          10        8.34      AU  2022-08-30 16:25:50
# ...

# %%
# Load csv2
second_cities_df =pd.read_csv("Resources/cities2.csv")
second_cities_df.head(10)
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     Emerald -23.5333  148.1667     57.34       100         100
# 1        1       Avera  33.1940  -82.5271     86.56        52          59
# 2        2    Cidreira -30.1811  -50.2056     60.13        71           5
# 3        3  Sangmélima   2.9333   11.9833     69.15        96          88
# 4        4      Harper   4.3750   -7.7169     77.67        77          40
# 5        5   Cape Town -33.9258   18.4232     60.12        47           0
# 6        6      Castro -24.7911  -50.0119     57.78        63          79
# 7        7      Atuona  -9.8000 -139.0333     77.20        67          42
# 8        8    Chimbote  -9.0853  -78.5783     67.87        69          64
# 9        9         Leh  34.1667   77.5833     63.45        41           8
#
#    Wind Speed Country                 date
# 0        4.61      AU  2022-08-30 18:17:55
# 1        4.00      US  2022-08-30 18:17:56
# ...

# %%
# Check for nulls on csv 1
first_cities_df.count()
# Out:
# City_ID       20
# City          20
# Lat           20
# Lng           20
# Max Temp      20
# Humidity      20
# Cloudiness    20
# Wind Speed    20
# Country       20
# date          20
# dtype: int64

# %%
# Check for nulls on csv 2
second_cities_df.count()
# Out:
# City_ID       20
# City          20
# Lat           20
# Lng           20
# Max Temp      20
# Humidity      20
# Cloudiness    20
# Wind Speed    20
# Country       20
# date          20
# dtype: int64

# %%
cities_data_complete_df = pd.merge(first_cities_df, second_cities_df, on=["City", "City"])
cities_data_complete_df.head()
# Out:
#    City_ID_x     City    Lat_x     Lng_x  Max Temp_x  Humidity_x  \
# 0          3   Atuona  -9.8000 -139.0333       76.73          69
# 1          5   Castro -24.7911  -50.0119       56.52          64
# 2          6  Ushuaia -54.8000  -68.3000       47.86          61
# 3         10   Albany  42.6001  -73.9662       88.43          65
#
#    Cloudiness_x  Wind Speed_x Country_x               date_x  City_ID_y  \
# 0            59         22.21        PF  2022-08-30 16:25:51          7
# 1            93         12.10        BR  2022-08-30 16:25:51          6
# 2            40          4.61        AR  2022-08-30 16:21:41         13
# 3            29          1.01        US  2022-08-30 16:23:12         10
#
#      Lat_y     Lng_y  Max Temp_y  Humidity_y  Cloudiness_y  Wind Speed_y  \
# 0  -9.8000 -139.0333       77.20          67            42         25.26
# 1 -24.7911  -50.0119       57.78          63            79         11.30
# ...

# %%
print(list(cities_data_complete_df.columns))
# Out:
# ['City_ID_x', 'City', 'Lat_x', 'Lng_x', 'Max Temp_x', 'Humidity_x', 'Cloudiness_x', 'Wind Speed_x', 'Country_x', 'date_x', 'City_ID_y', 'Lat_y', 'Lng_y', 'Max Temp_y', 'Humidity_y', 'Cloudiness_y', 'Wind Speed_y', 'Country_y', 'date_y']

# %%
# cities_data_complete_df.rename(columns = {'[0]':'temp_change'}, inplace = True)
# cities_data_complete_df.head()

# %%
temp_change= cities_data_complete_df["Max Temp_x"]-cities_data_complete_df["Max Temp_y"]
temp_change
# Out:
# 0   -0.47
# 1   -1.26
# 2   -1.80
# 3   -0.20
# dtype: float64

# %%
temp_change_df =pd.DataFrame(temp_change)
temp_change_df
# Out:
#       0
# 0 -0.47
# 1 -1.26
# 2 -1.80
# 3 -0.20

# %%
print(list(temp_change_df.columns))
# Out:
# [0]

# %%
temp_change_df.rename(columns={"[0]":'temp_change'}, inplace= True)
temp_change_df.head()
# Out:
#       0
# 0 -0.47
# 1 -1.26
# 2 -1.80
# 3 -0.20

# %%
final_complete_cities_df=cities_data_complete_df.join(temp_change_df) 
final_complete_cities_df
# Out:
#    City_ID_x     City    Lat_x     Lng_x  Max Temp_x  Humidity_x  \
# 0          3   Atuona  -9.8000 -139.0333       76.73          69
# 1          5   Castro -24.7911  -50.0119       56.52          64
# 2          6  Ushuaia -54.8000  -68.3000       47.86          61
# 3         10   Albany  42.6001  -73.9662       88.43          65
#
#    Cloudiness_x  Wind Speed_x Country_x               date_x  City_ID_y  \
# 0            59         22.21        PF  2022-08-30 16:25:51          7
# 1            93         12.10        BR  2022-08-30 16:25:51          6
# 2            40          4.61        AR  2022-08-30 16:21:41         13
# 3            29          1.01        US  2022-08-30 16:23:12         10
#
#      Lat_y     Lng_y  Max Temp_y  Humidity_y  Cloudiness_y  Wind Speed_y  \
# 0  -9.8000 -139.0333       77.20          67            42         25.26
# 1 -24.7911  -50.0119       57.78          63            79         11.30
# ...

# %%
final_complete_cities_df.rename(columns={0:'temp_change'}, inplace=True)
final_complete_cities_df.head()
# Out:
#    City_ID_x     City    Lat_x     Lng_x  Max Temp_x  Humidity_x  \
# 0          3   Atuona  -9.8000 -139.0333       76.73          69
# 1          5   Castro -24.7911  -50.0119       56.52          64
# 2          6  Ushuaia -54.8000  -68.3000       47.86          61
# 3         10   Albany  42.6001  -73.9662       88.43          65
#
#    Cloudiness_x  Wind Speed_x Country_x               date_x  City_ID_y  \
# 0            59         22.21        PF  2022-08-30 16:25:51          7
# 1            93         12.10        BR  2022-08-30 16:25:51          6
# 2            40          4.61        AR  2022-08-30 16:21:41         13
# 3            29          1.01        US  2022-08-30 16:23:12         10
#
#      Lat_y     Lng_y  Max Temp_y  Humidity_y  Cloudiness_y  Wind Speed_y  \
# 0  -9.8000 -139.0333       77.20          67            42         25.26
# 1 -24.7911  -50.0119       57.78          63            79         11.30
# ...

# %%
import time as dt

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
lines=final_complete_cities_df.plot()
# Save the figure.
plt.savefig(" Fig1.png")

# %%
final_complete_cities_df.plot(x="City", y=['temp_change'], kind= "bar",figsize=(9,8))
plt.savefig("tempchange.png")

# %%
# completed by Kelvin Mutua
